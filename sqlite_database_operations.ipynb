# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd

# %% [markdown]
# ## Download Dataset Number One
#
# For this assignment I will be analyzing hospital price transparency datasets of my choice

# %%
df= pd.read_excel('chs_st_joseph.xlsx')
df
# Out:
#        Billing/Charge Code                               Charge Description   \
# 0               3018437801    HC 1,5 ANHYDROGLUCITOL,INTERM GLY CNTRL Q10378
# 1               3018263400                               HC 11 DEOXYCORTISOL
# 2               3018414300                          HC 17 HYDROXPREGNENOLONE
# 3               3018349800                         HC 17 HYDROXYPROGESTERONE
# 4               3603621500                    HC 1ST ORD SEL CATH ART THORAC
# ...                    ...                                               ...
# 65023           6370000002                      XRX ZONISAMIDE 25 MG PO CAPS
# 65024           6370000002                      XRX ZONISAMIDE 50 MG PO CAPS
# 65025           6370000002                      XRX ZONISAMIDE 50 MG PO CAPS
# 65026           6370000002                      XRX ZONISAMIDE 50 MG PO CAPS
# 65027           6360000001  XRX ZOSTER VACCINE LIVE 19400 UNT/0.65ML SC SUSR
#
# ...

# %% [markdown]
# ## Understanding Dataset Shape

# %%
df.shape
# Out:
# (65028, 10)

# %%
df.sample(15)
# Out:
#        Billing/Charge Code                          Charge Description   \
# 5354            2791769296  HC SS BSCI GUIDWR ANGD GLIDE .018,C1769,403
# 52071           2780171302             ORMS&D XLP PLUS PLATE L4-L5 SZ 8
# 63061           6370000002       XRX RIVASTIGMINE TARTRATE 3 MG PO CAPS
# 46937           2780171300               ORMS&D T2 RECON NAIL SET SCREW
# 25657           2729000002                  ORMS&D FIXED DRILL 2.3X12MM
# 22819           2729000002          ORMS&D CUDA BLADE MICRO JOINT 2.9MM
# 44865           2780262500            ORMS&D STENT EVERFLEX 6 X 80 X 80
# 37493           2780177600          ORMS&D PSN FEM CR CMT CCR STD SZ9 L
# 62598           6370000002           XRX PROPAFENONE HCL 150 MG PO TABS
# 24367           2780178100            ORMS&D ETHICON ULTRAPRO MESH UMR3
# 58119           2500000001           XRX HYDROCORTISONE MICRONIZED POWD
# 17210           2780177600        ORMS&D BIOLOX DELTA FEM HEAD, 40MM, -
# ...

# %% [markdown]
# ## Looking For Missingness

# %%
df.columns
# Out:
# Index(['Billing/Charge Code', 'Charge Description ', 'Rev Code', 'CPT/HCPC',
#        'Price', 'NDC', 'Package Size', 'Package Unit', 'Package Description',
#        'Charge Quantity'],
#       dtype='object')

# %%
import re
def cleaning_columns (df):
    def clean_name(name):
        cleaned_name = re.sub(r'[^a-zA-Z0-9]', '', name)
        return cleaned_name.lower()

    df.columns = [clean_name(col) for col in df.columns]
    return df

df = cleaning_columns(df)
df
# Out:
#        billingchargecode                                 chargedescription  \
# 0             3018437801    HC 1,5 ANHYDROGLUCITOL,INTERM GLY CNTRL Q10378
# 1             3018263400                               HC 11 DEOXYCORTISOL
# 2             3018414300                          HC 17 HYDROXPREGNENOLONE
# 3             3018349800                         HC 17 HYDROXYPROGESTERONE
# 4             3603621500                    HC 1ST ORD SEL CATH ART THORAC
# ...                  ...                                               ...
# 65023         6370000002                      XRX ZONISAMIDE 25 MG PO CAPS
# 65024         6370000002                      XRX ZONISAMIDE 50 MG PO CAPS
# 65025         6370000002                      XRX ZONISAMIDE 50 MG PO CAPS
# 65026         6370000002                      XRX ZONISAMIDE 50 MG PO CAPS
# 65027         6360000001  XRX ZOSTER VACCINE LIVE 19400 UNT/0.65ML SC SUSR
#
# ...

# %%
df.columns
# Out:
# Index(['billingchargecode', 'chargedescription', 'revcode', 'cpthcpc', 'price',
#        'ndc', 'packagesize', 'packageunit', 'packagedescription',
#        'chargequantity'],
#       dtype='object')

# %% [markdown]
# ### Dropping Missing Values

# %%
df.dropna(subset=['cpthcpc','ndc','packagesize','packageunit','packagedescription','chargequantity'],inplace=True)
df
# Out:
#        billingchargecode                                  chargedescription  \
# 52316         6360000001  XRX (NICU) BEVACIZUMAB INTRAVITREAL INJECTION ...
# 52328         6360000001                    XRX ABATACEPT 125 MG/ML SC SOSY
# 52329         6360000001                       XRX ABATACEPT 250 MG IV SOLR
# 52330         6360000001                      XRX ABCIXIMAB 2 MG/ML IV SOLN
# 52331         6360349002                     XRX ABEMACICLIB 100 MG PO TABS
# ...                  ...                                                ...
# 65002         6360000001             XRX ZOLEDRONIC ACID 5 MG/100ML IV SOLN
# 65003         6360000001             XRX ZOLEDRONIC ACID 5 MG/100ML IV SOLN
# 65004         6360000001             XRX ZOLEDRONIC ACID 5 MG/100ML IV SOLN
# 65005         6360000001             XRX ZOLEDRONIC ACID 5 MG/100ML IV SOLN
# 65027         6360000001   XRX ZOSTER VACCINE LIVE 19400 UNT/0.65ML SC SUSR
#
# ...

# %% [markdown]
# ## Descriptive Analysis - Numerical

# %%
df.describe()
# Out:
#        billingchargecode      revcode          price  packagesize
# count       4.140000e+03  4140.000000    4140.000000  4140.000000
# mean        6.195973e+09   618.588406    3624.753382    62.376016
# std         7.610532e+08    78.393366   18289.269447   183.825265
# min         2.500000e+09   250.000000       1.000000     0.025000
# 25%         6.360000e+09   636.000000      38.000000     1.000000
# 50%         6.360000e+09   636.000000     133.000000     5.000000
# 75%         6.360000e+09   636.000000     781.750000    50.000000
# max         6.370000e+09   636.000000  431958.000000  5000.000000

# %% [markdown]
# Within this descriptive analysis the columns 'billingchargecode' and 'revcode' are codes and not numerical values therefore the statistics will be void for the purpose of this analysis. Within the desciptive statistics generated the 'price' statistics will be the most beneficial in analyzing the pricing of different categories.

# %% [markdown]
# ## Category Frequency Counts

# %%
df.value_counts('chargedescription')
# Out:
# chargedescription
# XRX FENTANYL CITRATE 50 MCG/ML IJ SOLN (WRAPPER)     33
# XRX FUROSEMIDE 10 MG/ML IJ SOLN                      33
# XRX SODIUM CHLORIDE 0.9 % IV SOLN                    32
# XRX HEPARIN SODIUM (PORCINE) 1000 UNIT/ML IJ SOLN    23
# XRX DOXORUBICIN HCL 2 MG/ML IV SOLN                  23
#                                                      ..
# XRX GLUCARPIDASE 1000 UNITS IV SOLR                   1
# XRX GLYCOPYRROLATE 1 MG/5ML IJ SOLN                   1
# XRX GLYCOPYRROLATE 1 MG/5ML IV SOSY                   1
# XRX GLYCOPYRROLATE PF 0.2 MG/ML IJ SOLN               1
# XRX ZOSTER VACCINE LIVE 19400 UNT/0.65ML SC SUSR      1
# Length: 1386, dtype: int64

# %%
df.value_counts('packagedescription')
# Out:
# packagedescription
# Vial          2500
# Flex Cont      519
# Syringe        364
# Bottle         208
# Bag            159
# Ampule         125
# Box             91
# Blister         60
# Glass Cont      47
# Plas Cont       33
# Cartridge        8
# Pen              7
# Crtrdg-NDL       5
# Cup              4
# Disp Pack        4
# Pump Btl         4
# Package          1
# Tube             1
# dtype: int64

# %% [markdown]
# ## Download Dataset Number Two

# %%
df1=pd.read_csv('stonybrook.csv')
df1
# Out:
#           Code                                        Description        Type  \
# 0        10004  FINE NEEDLE ASPIRATION BIOPSY, EACH ADDITIONAL...  Outpatient
# 1        10005  FINE NEEDLE ASPIRATION BIOPSY USING ULTRASOUND...  Outpatient
# 2        10005  FINE NEEDLE ASPIRATION BIOPSY USING ULTRASOUND...  Outpatient
# 3        10006  FINE NEEDLE ASPIRATION BIOPSY USING ULTRASOUND...  Outpatient
# 4        10009  FINE NEEDLE ASPIRATION BIOPSY OF GROWTH USING ...  Outpatient
# ...        ...                                                ...         ...
# 7705  30981203                             R&B SICU 09W1 ICR PT-Z         NaN
# 7706  30993018                               R&B TICR 09W2 - PT-I         NaN
# 7707  33500000                             R&B REV PICU 11S2 PT-X         NaN
# 7708  30333058                         ROPH HOSP.OBSERVATION PT-T         NaN
# 7709  30000004                                       SEMI-PRIVATE         NaN
#
# ...

# %% [markdown]
# ## Understanding the Shape

# %%
df1.shape
# Out:
# (7710, 57)

# %%
df1.sample(15)
# Out:
#           Code                                        Description        Type  \
# 3183     65275                         REPAIR OF LACERATED CORNEA  Outpatient
# 5835     J3590                             UNCLASSIFIED BIOLOGICS  Outpatient
# 91       11450  REMOVAL OF SKIN AND TISSUE OF UNDERARMS FOR IN...  Outpatient
# 7626  33703000                             R&B REV NICU 08S1 PT-J         NaN
# 4362     84087             PHOSPHOHEXOSE ISOMERASE (ENZYME) LEVEL  Outpatient
# 1641     35903            REMOVAL OF INFECTED GRAFT OF ARM OR LEG  Outpatient
# 6983  43301415                             US:PROCEDURE RM 1.5HRS         NaN
# 6755      750X                                      Schizophrenia   Inpatient
# 1365     29874  REMOVAL OF LOOSE OR FOREIGN BODY IN KNEE JOINT...  Outpatient
# 4027     78264  NUCLEAR MEDICINE STUDY OF STOMACH TO ASSESS EM...  Outpatient
# 28       10160              ASPIRATION OF ABSCESS, BLOOD, OR CYST  Outpatient
# ...

# %% [markdown]
# ## Looking for Missingness

# %%
df1.columns
# Out:
# Index(['Code', 'Description', 'Type', 'Package/Line_Level', 'Gross charge',
#        'Discounted cash price', 'De-identified min contracted rate',
#        'De-identified max contracted rate', 'Derived contracted rate',
#        '1199-Commercial other', 'Aetna-Medicare Advantage HMO',
#        'Aetna-Commercial HMO/POS', 'Aetna-Commercial PPO/Open Access',
#        'Aetna-Commercial other', 'Empire Health-Commercial other',
#        'Empire Health-Commercial PPO/Open Access',
#        'BlueCross BlueShield-Commercial other',
#        'Beacon Health-Commercial other', 'Carelon Health-Commercial other',
#        'Cigna-Commercial PPO/Open Access', 'Cigna-Commercial other',
#        'Cigna-Commercial HMO/POS', 'EH Facet-Commercial other',
#        'EmblemHealth-Commercial PPO/Open Access',
#        'EmblemHealth-Commercial other', 'EmblemHealth-Commercial HMO/POS',
#        'EmblemHealth-Medicaid HMO', 'EmblemHealth-Medicare Advantage HMO',
#        'Empire Health-Commercial HMO/POS',
# ...

# %%
import re
def cleaning_columns (df1):
    def clean_name(name):
        cleaned_name = re.sub(r'[^a-zA-Z0-9]', '', name)
        return cleaned_name.lower()

    df1.columns = [clean_name(col) for col in df1.columns]
    return df1

df1 = cleaning_columns(df1)
df1
# Out:
#           code                                        description        type  \
# 0        10004  FINE NEEDLE ASPIRATION BIOPSY, EACH ADDITIONAL...  Outpatient
# 1        10005  FINE NEEDLE ASPIRATION BIOPSY USING ULTRASOUND...  Outpatient
# 2        10005  FINE NEEDLE ASPIRATION BIOPSY USING ULTRASOUND...  Outpatient
# 3        10006  FINE NEEDLE ASPIRATION BIOPSY USING ULTRASOUND...  Outpatient
# 4        10009  FINE NEEDLE ASPIRATION BIOPSY OF GROWTH USING ...  Outpatient
# ...        ...                                                ...         ...
# 7705  30981203                             R&B SICU 09W1 ICR PT-Z         NaN
# 7706  30993018                               R&B TICR 09W2 - PT-I         NaN
# 7707  33500000                             R&B REV PICU 11S2 PT-X         NaN
# 7708  30333058                         ROPH HOSP.OBSERVATION PT-T         NaN
# 7709  30000004                                       SEMI-PRIVATE         NaN
#
# ...

# %% [markdown]
# ## Dropping Missing Values

# %%
df1.dropna
# Out:
# <bound method DataFrame.dropna of           code                                        description        type  \
# 0        10004  FINE NEEDLE ASPIRATION BIOPSY, EACH ADDITIONAL...  Outpatient
# 1        10005  FINE NEEDLE ASPIRATION BIOPSY USING ULTRASOUND...  Outpatient
# 2        10005  FINE NEEDLE ASPIRATION BIOPSY USING ULTRASOUND...  Outpatient
# 3        10006  FINE NEEDLE ASPIRATION BIOPSY USING ULTRASOUND...  Outpatient
# 4        10009  FINE NEEDLE ASPIRATION BIOPSY OF GROWTH USING ...  Outpatient
# ...        ...                                                ...         ...
# 7705  30981203                             R&B SICU 09W1 ICR PT-Z         NaN
# 7706  30993018                               R&B TICR 09W2 - PT-I         NaN
# 7707  33500000                             R&B REV PICU 11S2 PT-X         NaN
# 7708  30333058                         ROPH HOSP.OBSERVATION PT-T         NaN
# 7709  30000004                                       SEMI-PRIVATE         NaN
#
# ...

# %%
df1.isnull()
df1.isnull().sum()
# Out:
# code                                          0
# description                                   0
# type                                        783
# packagelinelevel                            783
# grosscharge                                   0
# discountedcashprice                           0
# deidentifiedmincontractedrate              1456
# deidentifiedmaxcontractedrate              1456
# derivedcontractedrate                      1456
# 1199commercialother                        6696
# aetnamedicareadvantagehmo                  6604
# aetnacommercialhmopos                      5883
# aetnacommercialppoopenaccess               6098
# aetnacommercialother                       7582
# empirehealthcommercialother                4650
# empirehealthcommercialppoopenaccess        5308
# bluecrossblueshieldcommercialother         6456
# beaconhealthcommercialother                7707
# carelonhealthcommercialother               7707
# cignacommercialppoopenaccess               5744
# ...

# %% [markdown]
# Due to there being no rows remaining after removing all the rows with missing information, for the purpose of this analysis we will be keeping all rows with NaN inputs.

# %% [markdown]
# ## Descriptive Analysis - Numerical

# %%
df1.describe().round(2)
# Out:
#        grosscharge  discountedcashprice  deidentifiedmincontractedrate  \
# count      7710.00              7710.00                        6254.00
# mean      22748.32             22748.32                        4090.69
# std       74705.70             74705.70                       10576.21
# min           0.03                 0.03                           0.01
# 25%        1065.90              1065.90                          96.52
# 50%        4745.30              4745.30                        1108.86
# 75%       11038.81             11038.81                        4309.53
# max     1857952.44           1857952.44                      327869.69
#
#        deidentifiedmaxcontractedrate  derivedcontractedrate  \
# count                        6254.00                6254.00
# mean                        10035.79                6315.59
# std                         29150.75               14601.85
# min                             0.10                   0.03
# ...

# %% [markdown]
# ## Frequency Counts
#
# For categorical data which we can use to analyze hospital cost trends.

# %%
df1.value_counts('description')
# Out:
# description
# R&B SHA 05PS/11PS SEMI-PRIVATE                                                                                3
# R&B MED 05CA SEMI-PRIVATE/2                                                                                   3
# MRI SCAN OF CHEST WITHOUT CONTRAST                                                                            2
# INFUSION INTO A VEIN FOR THERAPY, PREVENTION, OR DIAGNOSIS, 1 HOUR OR LESS                                    2
# INFUSION INTO A VEIN FOR THERAPY, PREVENTION, OR DIAGNOSIS, ADDITIONAL SEQUENTIAL INFUSION, 1 HOUR OR LESS    2
#                                                                                                              ..
# INJECTION, VANCOMYCIN HCL (MYLAN) NOT THERAPEUTICALLY EQUIVALENT TO J3370, 500 MG                             1
# INJECTION, VANCOMYCIN HCL, 500 MG                                                                             1
# ...

# %%
df1.value_counts('type')
# Out:
# type
# Outpatient    6041
# Inpatient      886
# dtype: int64

# %%
df1.value_counts('packagelinelevel')
# Out:
# packagelinelevel
# Line       4691
# Package    2236
# dtype: int64

# %% [markdown]
# ## SQLite Database Operations

# %% [markdown]
# ### Importing Packages

# %%
from sqlalchemy import create_engine
import sqlite3

# %% [markdown]
# ### Creating a Local SQLite Database

# %%
conn = sqlite3.connect('health.db')
c = conn.cursor()
